# %% [markdown]
# # Checkup of User Goals and Devices

# %%
from IPython.display import display, Markdown
import snakemd

import fitfile
import garmindb
from garmindb import GarminConnectConfigManager
from garmindb.garmindb import GarminDb, Device, DeviceInfo, ActivitiesDb, Activities, ActivityLaps, ActivityRecords, StepsActivities

doc = snakemd.new_doc()

gc_config = GarminConnectConfigManager()
db_params_dict = gc_config.get_db_params()

garmin_db = GarminDb(db_params_dict)

checkup = garmindb.Checkup(paragraph_func=doc.add_paragraph, heading_func=doc.add_heading)

doc.add_heading("Goals", 2)
checkup.goals()

doc.add_heading("Devices with Low Batteries", 2)

devices = Device.get_all(garmin_db)
for device in devices:
    battery_level = DeviceInfo.get_col_latest_where(garmin_db, DeviceInfo.battery_status,
                                                    [DeviceInfo.serial_number == device.serial_number,
                                                        DeviceInfo.battery_status != fitfile.field_enums.BatteryStatus.invalid])
    if battery_level is fitfile.field_enums.BatteryStatus.low:
        doc.add_paragraph(f"Device {device.manufacturer} {device.product} ({device.serial_number}) has a low battery")

display(Markdown(str(doc)))
# Out:
# ## Goals
#
# Steps: goal not met on 2024-06-02
#
# Floors: goal not met on 2024-06-02
#
# Steps: goal not met on 2024-06-03
#
# Floors: goal not met on 2024-06-03
#
# Steps: goal not met on 2024-06-04
#
# Floors: goal not met on 2024-06-04
#
# Steps: goal not met on 2024-06-05
#
# Floors: goal not met on 2024-06-05
#
# Steps: goal not met on 2024-06-06
#
# Floors: goal not met on 2024-06-06
#
# Floors: goal not met on 2024-06-07
#
# Steps: goal not met on 2024-06-08
#
# Floors: goal not met on 2024-06-08
#
# Steps: goal not met on 2024-06-09
#
# Floors: goal not met on 2024-06-09
#
# Steps: goal not met 6 days for week ending in 2024-06-09
#
# Floors: goal not met 7 days for week ending in 2024-06-09
#
# Intensity mins: goal not met for week ending in 2024-06-09
#
# Steps: goal not met on 2024-06-10
#
# Floors: goal not met on 2024-06-10
#
# Floors: goal not met on 2024-06-11
#
# Floors: goal not met on 2024-06-12
#
# Steps: goal not met on 2024-06-13
#
# Floors: goal not met on 2024-06-13
#
# Steps: goal not met on 2024-06-14
#
# Floors: goal not met on 2024-06-14
#
# Floors: goal not met on 2024-06-15
#
# Steps: goal not met on 2024-06-16
#
# Floors: goal not met on 2024-06-16
#
# Steps: goal not met 4 days for week ending in 2024-06-16
#
# Floors: goal not met 7 days for week ending in 2024-06-16
#
# Intensity mins: goal not met for week ending in 2024-06-16
#
# Steps: goal not met on 2024-06-17
#
# Floors: goal not met on 2024-06-17
#
# Floors: goal not met on 2024-06-18
#
# Floors: goal not met on 2024-06-19
#
# Steps: goal not met on 2024-06-20
#
# Floors: goal not met on 2024-06-20
#
# Floors: goal not met on 2024-06-21
#
# Floors: goal not met on 2024-06-22
#
# Steps: goal not met on 2024-06-23
#
# Floors: goal not met on 2024-06-23
#
# Steps: goal not met 3 days for week ending in 2024-06-23
#
# Floors: goal not met 7 days for week ending in 2024-06-23
#
# Intensity mins: goal not met for week ending in 2024-06-23
#
# Steps: goal not met on 2024-06-24
#
# Floors: goal not met on 2024-06-24
#
# Floors: goal not met on 2024-06-25
#
# Floors: goal not met on 2024-06-26
#
# Steps: goal not met on 2024-06-27
#
# Floors: goal not met on 2024-06-27
#
# Floors: goal not met on 2024-06-28
#
# Steps: goal not met on 2024-06-29
#
# Floors: goal not met on 2024-06-29
#
# Steps: goal not met on 2024-06-30
#
# Floors: goal not met on 2024-06-30
#
# Steps: goal not met 4 days for week ending in 2024-06-30
#
# Floors: goal not met 7 days for week ending in 2024-06-30
#
# Intensity mins: goal not met for week ending in 2024-06-30
#
# Floors: goal not met on 2024-07-01
#
# Steps: goal not met on 2024-07-02
#
# Floors: goal not met on 2024-07-02
#
# Floors: goal not met on 2024-07-03
#
# Floors: goal not met on 2024-07-04
#
# Floors: goal not met on 2024-07-05
#
# Steps: goal not met on 2024-07-06
#
# Floors: goal not met on 2024-07-06
#
# Floors: goal not met on 2024-07-07
#
# Steps: goal not met 2 days for week ending in 2024-07-07
#
# Floors: goal not met 7 days for week ending in 2024-07-07
#
# Intensity mins: goal not met for week ending in 2024-07-07
#
# Steps: goal not met on 2024-07-08
#
# Floors: goal not met on 2024-07-08
#
# Floors: goal not met on 2024-07-09
#
# Steps: goal not met on 2024-07-10
#
# Floors: goal not met on 2024-07-10
#
# Floors: goal not met on 2024-07-11
#
# Steps: goal not met on 2024-07-12
#
# Floors: goal not met on 2024-07-12
#
# Steps: goal not met on 2024-07-13
#
# Floors: goal not met on 2024-07-13
#
# Floors: goal not met on 2024-07-14
#
# Steps: goal not met 4 days for week ending in 2024-07-14
#
# Floors: goal not met 7 days for week ending in 2024-07-14
#
# Intensity mins: goal not met for week ending in 2024-07-14
#
# Steps: goal not met on 2024-07-15
#
# Floors: goal not met on 2024-07-15
#
# Steps: goal not met on 2024-07-16
#
# Floors: goal not met on 2024-07-16
#
# Floors: goal not met on 2024-07-17
#
# Steps: goal not met on 2024-07-18
#
# Floors: goal not met on 2024-07-18
#
# Floors: goal not met on 2024-07-19
#
# Floors: goal not met on 2024-07-20
#
# Steps: goal not met on 2024-07-21
#
# Floors: goal not met on 2024-07-21
#
# Steps: goal not met 4 days for week ending in 2024-07-21
#
# Floors: goal not met 7 days for week ending in 2024-07-21
#
# Intensity mins: goal not met for week ending in 2024-07-21
#
# Steps: goal not met on 2024-07-22
#
# Floors: goal not met on 2024-07-22
#
# Floors: goal not met on 2024-07-23
#
# Steps: goal not met on 2024-07-24
#
# Floors: goal not met on 2024-07-24
#
# Steps: goal not met on 2024-07-25
#
# Floors: goal not met on 2024-07-25
#
# Floors: goal not met on 2024-07-26
#
# Steps: goal not met on 2024-07-27
#
# Floors: goal not met on 2024-07-27
#
# Steps: goal not met on 2024-07-28
#
# Floors: goal not met on 2024-07-28
#
# Steps: goal not met 5 days for week ending in 2024-07-28
#
# Floors: goal not met 7 days for week ending in 2024-07-28
#
# Intensity mins: goal not met for week ending in 2024-07-28
#
# Floors: goal not met on 2024-07-29
#
# Floors: goal not met on 2024-07-30
#
# Floors: goal not met on 2024-07-31
#
# Steps: goal not met on 2024-08-01
#
# Floors: goal not met on 2024-08-01
#
# Floors: goal not met on 2024-08-02
#
# Steps: goal not met on 2024-08-03
#
# Floors: goal not met on 2024-08-03
#
# Floors: goal not met on 2024-08-04
#
# Steps: goal not met 2 days for week ending in 2024-08-04
#
# Floors: goal not met 7 days for week ending in 2024-08-04
#
# Intensity mins: goal not met for week ending in 2024-08-04
#
# Floors: goal not met on 2024-08-05
#
# Floors: goal not met on 2024-08-06
#
# Floors: goal not met on 2024-08-07
#
# Steps: goal not met on 2024-08-08
#
# Floors: goal not met on 2024-08-08
#
# Steps: goal not met on 2024-08-09
#
# Floors: goal not met on 2024-08-09
#
# Steps: goal not met on 2024-08-10
#
# Floors: goal not met on 2024-08-10
#
# Floors: goal not met on 2024-08-11
#
# Steps: goal not met 3 days for week ending in 2024-08-11
#
# Floors: goal not met 7 days for week ending in 2024-08-11
#
# Intensity mins: goal not met for week ending in 2024-08-11
#
# Steps: goal not met on 2024-08-12
#
# Floors: goal not met on 2024-08-12
#
# Floors: goal not met on 2024-08-13
#
# Steps: goal not met on 2024-08-14
#
# Floors: goal not met on 2024-08-14
#
# Steps: goal not met on 2024-08-15
#
# Floors: goal not met on 2024-08-15
#
# Floors: goal not met on 2024-08-16
#
# Floors: goal not met on 2024-08-17
#
# Steps: goal not met on 2024-08-18
#
# Floors: goal not met on 2024-08-18
#
# Steps: goal not met 4 days for week ending in 2024-08-18
#
# Floors: goal not met 7 days for week ending in 2024-08-18
#
# Intensity mins: goal not met for week ending in 2024-08-18
#
# Floors: goal not met on 2024-08-19
#
# Floors: goal not met on 2024-08-20
#
# Steps: goal not met on 2024-08-21
#
# Floors: goal not met on 2024-08-21
#
# Floors: goal not met on 2024-08-22
#
# Floors: goal not met on 2024-08-23
#
# Steps: goal not met on 2024-08-24
#
# Floors: goal not met on 2024-08-24
#
# Steps: goal not met on 2024-08-25
#
# Floors: goal not met on 2024-08-25
#
# Steps: goal not met 3 days for week ending in 2024-08-25
#
# Floors: goal not met 7 days for week ending in 2024-08-25
#
# Intensity mins: goal not met for week ending in 2024-08-25
#
# Steps: goal not met on 2024-08-26
#
# Floors: goal not met on 2024-08-26
#
# Steps: goal not met on 2024-08-27
#
# Floors: goal not met on 2024-08-27
#
# Floors: goal not met on 2024-08-28
#
# Steps: goal not met on 2024-08-29
#
# Floors: goal not met on 2024-08-29
#
# # Summary:
#
# Steps: met goal 41 of last 90 days
#
# Floors: met goal 0 of last 90 days
#
# Intensity mins: met goal 0 of last 12 weeks
#
# ## Devices with Low Batteries
