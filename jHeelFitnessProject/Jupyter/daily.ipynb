# %% [markdown]
# # Daily Summaries for the Last Seven Days

# %%
import datetime
from IPython.display import display, Markdown
import snakemd

from garmindb import GarminConnectConfigManager
from garmindb.garmindb import GarminSummaryDb, DaysSummary

from jupyter_funcs import format_number
from graphs import Graph


def __render_day(garmin_sum_db, graph, date):
    day = DaysSummary.get_day(garmin_sum_db, date)
    if day:
        doc = snakemd.new_doc()
        doc.add_heading(f"Summary of {date}")
        doc.add_table(['Weight', 'Resting HR', 'Max HR', 'Waking Avg RR', 'Steps', 'Floors', 'Intensity Mins', 'Calories', 'Sleep', 'REM Sleep', 'Stress', 'Body Battery Max'],
            [
                [format_number(day.weight_avg), day.rhr_avg, day.hr_max, day.rr_waking_avg, day.steps, format_number(day.floors, 1),
                 day.intensity_time, day.calories_avg, day.sleep_avg, day.rem_sleep_avg, day.stress_avg, day.bb_max]
            ]
        )
        display(Markdown(str(doc)))
    graph.graph_date(date)


gc_config = GarminConnectConfigManager()
db_params_dict = gc_config.get_db_params()
garmin_sum_db = GarminSummaryDb(db_params_dict)

graph = Graph()

__render_day(garmin_sum_db, graph, datetime.date.today())

# %%
__render_day(garmin_sum_db, graph, datetime.date.today() - datetime.timedelta(days = 1))
# Out:
# # Summary of 2024-10-30
#
# | Weight | Resting HR | Max HR | Waking Avg RR | Steps | Floors | Intensity Mins | Calories | Sleep    | REM Sleep | Stress | Body Battery Max |
# | ------ | ---------- | ------ | ------------- | ----- | ------ | -------------- | -------- | -------- | --------- | ------ | ---------------- |
# | -      | None       | None   | None          | None  | -      | 00:00:00       | None     | 00:00:00 | 00:00:00  | None   | None             |

# %%
__render_day(garmin_sum_db, graph, datetime.date.today() - datetime.timedelta(days = 2))
# Out:
# # Summary of 2024-10-29
#
# | Weight | Resting HR | Max HR | Waking Avg RR | Steps | Floors | Intensity Mins | Calories | Sleep    | REM Sleep | Stress | Body Battery Max |
# | ------ | ---------- | ------ | ------------- | ----- | ------ | -------------- | -------- | -------- | --------- | ------ | ---------------- |
# | -      | 61.0       | 114.0  | 14.0          | 7005  | 0.0    | 00:31:00       | 2722     | 07:28:00 | 01:31:00  | 37     | 66               |

# %%
__render_day(garmin_sum_db, graph, datetime.date.today() - datetime.timedelta(days = 3))
# Out:
# # Summary of 2024-10-28
#
# | Weight | Resting HR | Max HR | Waking Avg RR | Steps | Floors | Intensity Mins | Calories | Sleep    | REM Sleep | Stress | Body Battery Max |
# | ------ | ---------- | ------ | ------------- | ----- | ------ | -------------- | -------- | -------- | --------- | ------ | ---------------- |
# | -      | 56.0       | 110.0  | 14.0          | 6049  | 0.0    | 00:01:00       | 2516     | 07:37:00 | 00:45:00  | 27     | 76               |

# %%
__render_day(garmin_sum_db, graph, datetime.date.today() - datetime.timedelta(days = 4))
# Out:
# # Summary of 2024-10-27
#
# | Weight | Resting HR | Max HR | Waking Avg RR | Steps | Floors | Intensity Mins | Calories | Sleep    | REM Sleep | Stress | Body Battery Max |
# | ------ | ---------- | ------ | ------------- | ----- | ------ | -------------- | -------- | -------- | --------- | ------ | ---------------- |
# | -      | 59.0       | 134.0  | 14.0          | 9657  | 0.0    | 02:02:00       | 3153     | 08:22:00 | 01:16:00  | 30     | 80               |

# %%
__render_day(garmin_sum_db, graph, datetime.date.today() - datetime.timedelta(days = 5))
# Out:
# # Summary of 2024-10-26
#
# | Weight | Resting HR | Max HR | Waking Avg RR | Steps | Floors | Intensity Mins | Calories | Sleep    | REM Sleep | Stress | Body Battery Max |
# | ------ | ---------- | ------ | ------------- | ----- | ------ | -------------- | -------- | -------- | --------- | ------ | ---------------- |
# | -      | 60.0       | 144.0  | 14.0          | 11179 | 0.0    | 01:25:00       | 3068     | 08:10:00 | 00:29:00  | 32     | 54               |

# %%
__render_day(garmin_sum_db, graph, datetime.date.today() - datetime.timedelta(days = 6))
# Out:
# # Summary of 2024-10-25
#
# | Weight | Resting HR | Max HR | Waking Avg RR | Steps | Floors | Intensity Mins | Calories | Sleep    | REM Sleep | Stress | Body Battery Max |
# | ------ | ---------- | ------ | ------------- | ----- | ------ | -------------- | -------- | -------- | --------- | ------ | ---------------- |
# | -      | 63.0       | 120.0  | 14.0          | 6765  | 0.0    | 00:21:00       | 2871     | 06:00:00 | 01:03:00  | 36     | 41               |

# %%
__render_day(garmin_sum_db, graph, datetime.date.today() - datetime.timedelta(days = 7))
# Out:
# # Summary of 2024-10-24
#
# | Weight | Resting HR | Max HR | Waking Avg RR | Steps | Floors | Intensity Mins | Calories | Sleep    | REM Sleep | Stress | Body Battery Max |
# | ------ | ---------- | ------ | ------------- | ----- | ------ | -------------- | -------- | -------- | --------- | ------ | ---------------- |
# | -      | 62.0       | 136.0  | 14.0          | 6923  | 0.0    | 00:45:00       | 2760     | 06:02:00 | 00:45:00  | 33     | 31               |
