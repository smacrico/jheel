# %% [markdown]
# # Daily Summaries for the Last Seven Days

# %%
import datetime
from IPython.display import display, Markdown
import snakemd

from garmindb import ConfigManager
from garmindb.garmindb import GarminSummaryDb, DaysSummary


from jupyter_funcs import format_number
from graphs import Graph


def __render_day(garmin_sum_db, graph, date):
    day = DaysSummary.get_day(garmin_sum_db, date)
    if day:
        doc = snakemd.new_doc()
        doc.add_heading(f"Summary of {date}")
        doc.add_table(['Weight', 'Resting HR', 'Max HR', 'Min HR', 'Waking Avg RR', 'Steps', 'Floors', 'Intensity Mins', 'Calories', 'Sleep', 'REM Sleep', 'Stress'],
            [
                [format_number(day.weight_avg), day.rhr_avg, day.hr_max, day.hr_min, day.rr_waking_avg, day.steps, format_number(day.floors, 1),
                 day.intensity_time, day.calories_avg, day.sleep_avg, day.rem_sleep_avg, day.stress_avg]
            ]
        )
        display(Markdown(str(doc)))
    graph.graph_date(date)


db_params_dict = ConfigManager.get_db_params()
garmin_sum_db = GarminSummaryDb(db_params_dict)

graph = Graph()

# %%
__render_day(garmin_sum_db, graph, datetime.date.today() - datetime.timedelta(days = 1))
# Out:
# # Summary of 2024-03-05
#
# | Weight | Resting HR | Max HR | Min HR | Waking Avg RR | Steps | Floors | Intensity Mins | Calories | Sleep    | REM Sleep | Stress |
# | ------ | ---------- | ------ | ------ | ------------- | ----- | ------ | -------------- | -------- | -------- | --------- | ------ |
# | -      | 55.0       | 115.0  | 46.0   | 14.0          | 5349  | 0.0    | 00:15:00       | 2529     | 07:13:00 | 01:14:00  | 35     |

# %%
__render_day(garmin_sum_db, graph, datetime.date.today() - datetime.timedelta(days = 2))
# Out:
# # Summary of 2024-03-04
#
# | Weight | Resting HR | Max HR | Min HR | Waking Avg RR | Steps | Floors | Intensity Mins | Calories | Sleep    | REM Sleep | Stress |
# | ------ | ---------- | ------ | ------ | ------------- | ----- | ------ | -------------- | -------- | -------- | --------- | ------ |
# | -      | 55.0       | 111.0  | 52.0   | 15.0          | 5722  | 0.0    | 00:00:00       | 2667     | 08:14:00 | 01:28:00  | 33     |

# %%
__render_day(garmin_sum_db, graph, datetime.date.today() - datetime.timedelta(days = 3))
# Out:
# # Summary of 2024-03-03
#
# | Weight | Resting HR | Max HR | Min HR | Waking Avg RR | Steps | Floors | Intensity Mins | Calories | Sleep    | REM Sleep | Stress |
# | ------ | ---------- | ------ | ------ | ------------- | ----- | ------ | -------------- | -------- | -------- | --------- | ------ |
# | -      | 54.0       | 116.0  | 50.0   | 14.0          | 5536  | 0.0    | 00:05:00       | 2741     | 06:02:00 | 00:19:00  | 41     |

# %%
__render_day(garmin_sum_db, graph, datetime.date.today() - datetime.timedelta(days = 4))
# Out:
# # Summary of 2024-03-01
#
# | Weight | Resting HR | Max HR | Waking Avg RR | Steps | Floors | Intensity Mins | Calories | Sleep    | REM Sleep | Stress |
# | ------ | ---------- | ------ | ------------- | ----- | ------ | -------------- | -------- | -------- | --------- | ------ |
# | -      | 59.0       | 114.0  | 14.0          | 6015  | 0.0    | 00:28:00       | 2657     | 05:34:00 | 01:09:00  | 41     |

# %%
__render_day(garmin_sum_db, graph, datetime.date.today() - datetime.timedelta(days = 5))
# Out:
# # Summary of 2024-02-29
#
# | Weight | Resting HR | Max HR | Waking Avg RR | Steps | Floors | Intensity Mins | Calories | Sleep    | REM Sleep | Stress |
# | ------ | ---------- | ------ | ------------- | ----- | ------ | -------------- | -------- | -------- | --------- | ------ |
# | -      | 54.0       | 123.0  | 14.0          | 6629  | 0.0    | 00:28:00       | 2668     | 07:28:00 | 01:02:00  | 40     |

# %%
__render_day(garmin_sum_db, graph, datetime.date.today() - datetime.timedelta(days = 6))
# Out:
# # Summary of 2024-02-28
#
# | Weight | Resting HR | Max HR | Waking Avg RR | Steps | Floors | Intensity Mins | Calories | Sleep    | REM Sleep | Stress |
# | ------ | ---------- | ------ | ------------- | ----- | ------ | -------------- | -------- | -------- | --------- | ------ |
# | -      | 56.0       | 150.0  | 14.0          | 7839  | 0.0    | 00:47:00       | 2666     | 06:26:00 | 01:08:00  | 29     |

# %%
__render_day(garmin_sum_db, graph, datetime.date.today() - datetime.timedelta(days = 7))
# Out:
# # Summary of 2024-02-27
#
# | Weight | Resting HR | Max HR | Waking Avg RR | Steps | Floors | Intensity Mins | Calories | Sleep    | REM Sleep | Stress |
# | ------ | ---------- | ------ | ------------- | ----- | ------ | -------------- | -------- | -------- | --------- | ------ |
# | -      | 55.0       | 112.0  | 14.0          | 7946  | 0.0    | 00:23:00       | 2625     | 06:37:00 | 00:32:00  | 37     |
